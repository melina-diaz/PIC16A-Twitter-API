# %%
import making_dataframe
import analysis

# %%
making_dataframe.make_call('AAAAAAAAAAAAAAAAAAAAAKVtZgEAAAAAl9ydWGRRbzGoJ%2BtX9BQX2nqJOnI%3DDEZ9oWPKslhrVmlTMxyKbiWybhABOyAjLgGGhdZwAK0N9xrm8W',"from:UCLA -is:retweet","uclauser" )
#bearer_token removed for security reasons
# Out:
# Endpoint Response Code: 200

# %%
obj=analysis.Analysis("uclatweets.csv")

# %% [markdown]
# **(explanation of columns. x means of tweet, y means of user)**

# %%
obj.df.head()
# Out:
#                                                 text                 id_x  \
# 0  @UCLANeurology @NathanASmith1 @UCLA @UCLAHealt...  1502207380196519938
# 1  UCLA vs USC College Basketball Prediction, Gam...  1502206676836962305
# 2  UCLA vs USC College Basketball Prediction, Gam...  1502202338198667265
# 3  UCLA vs USC College Basketball Prediction, Gam...  1502202065958977538
# 4  UCLA vs USC College Basketball Prediction, Gam...  1502198935024189442
#
#                                    referenced_tweets  \
# 0  [{'type': 'replied_to', 'id': '150128663732560...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                created_at_x  geo  retweet_count_x  reply_count_x  \
# 0  2022-03-11T08:58:43.000Z  NaN                0              0
# 1  2022-03-11T08:55:56.000Z  NaN                0              0
# 2  2022-03-11T08:38:41.000Z  NaN                0              0
# 3  2022-03-11T08:37:36.000Z  NaN                0              0
# 4  2022-03-11T08:25:10.000Z  NaN                0              0
#
#    like_count_x              created_at_y         username description  \
# 0             0  2022-01-31T00:26:39.000Z  ariasleopoldo88         NaN
# 1             0  2021-11-28T13:20:44.000Z   AouabdiaYakoub         NaN
# 2             0  2021-11-28T13:20:44.000Z   AouabdiaYakoub         NaN
# 3             0  2021-11-28T13:20:44.000Z   AouabdiaYakoub         NaN
# 4             0  2021-11-28T13:20:44.000Z   AouabdiaYakoub         NaN
#
#                   id_y             name  verified  followers_count_y  \
# 0  1487945232872194048   Leopoldo Arias     False                  0
# 1  1464947304264261636  Yakoub Aouabdia     False                 35
# 2  1464947304264261636  Yakoub Aouabdia     False                 35
# 3  1464947304264261636  Yakoub Aouabdia     False                 35
# 4  1464947304264261636  Yakoub Aouabdia     False                 35
#
#    following_count_y  tweet_count_y  listed_count_y
# 0                 21            507               0
# 1                 22          76108               0
# 2                 22          76108               0
# 3                 22          76108               0
# 4                 22          76108               0

# %%
obj.popularity(10)
# Out:
# #1 with 24 popularity score:
# #USC vs. UCLA at 8:30 p.m. on Friday night. Most importantly, it's on FS1
#
# #2 with 20 popularity score:
# UCLA vs. USC, Round 3
#
# Saturday, 8:30 p.m.
#
# Book it
#
# #3 with 12 popularity score:
# Tommorow night:
#
# Baseball: USC vs UCLA @ Jackie Robinson Stadium -- 5 p.m.
#
# Men's basketball: No. 3 USC vs No. 2 UCLA @ T-Mobile Arena -- 8:30 p.m.
#
# #4 with 12 popularity score:
# UCLA, USC, Colorado State ML Parlay +140 was not worth the stress at all but 💰
#
# #5 with 11 popularity score:
# Fight on all the way to the finish. ✌️
#
# @USC_Hoops outlasts Washington 65-61 to set up a rubber match against crosstown rival UCLA in the semifinals.
#
# #FightOn | #Pac12MBB | @Vegas https://t.co/OPuaUscgZD
#
# #6 with 6 popularity score:
# Last Saturday after the loss against UCLA, Boogie said his ankle was "feeling better," but there was still ice wrapped around his ankle postgame. No ice tonight, only black slippers for the junior guard.
#
# #7 with 6 popularity score:
# Can't get another chance at UCLA without winning tonight. So as painful as it was it's a win
#
# #8 with 5 popularity score:
# So USC -UCLA rubber match tomorrow
#
# #9 with 5 popularity score:
# You right, the correct link is:
#     https://t.co/rGHIc9kH0O https://t.co/GUV6vxpRDS
#
# #10 with 5 popularity score:
# #USC played a bad game and won.
#
# Guys should feel relieved and intent on fixing this stuff against UCLA in the rubber match (series tied, 1-1).

# %%
obj.get_topics(10, 5)
# Out:
# ['ucla' 'usc' 'parlay' 'state' 'ml']
# ['basketball' 'game' 'ucla' 'vs' 'usc']
# ['24' 'ncaa' 'pac12tournament' '65' '19']
# ['best' 'link' 'usc' 'minutes' 'sports']
# ['better' 'homelessness' 'tomorrow' 'tonight' 'ucla']
# ['probably' 'ucla' 'bad' 'going' 'team']
# ['227' 'nba' 'bruins' 'spicy' 'chili']
# ['guys' 'ucla' 'cal' 'like' 'wear']
# ['trojans' '65' '61' 'ucla' 'amp']
# ['jaquez' 'washington' 'tournament' 'pac' '12']

# %%
obj.get_sentiment()
# Out:
# C:\Users\melinadiaz\source\PIC16A\PIC16A-Twitter-API\analysis.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['sentiment'] = df1['text'].apply(get_sentiment)
# (<Figure size 360x360 with 1 Axes>,
#  <module 'matplotlib.pyplot' from 'C:\\Users\\melinadiaz\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>,
#  <module 'matplotlib.pyplot' from 'C:\\Users\\melinadiaz\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>,
#  <module 'matplotlib.pyplot' from 'C:\\Users\\melinadiaz\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>)

# %%
obj.df[obj.df['text'].str.contains("Chili")]
# Out:
#                                                  text                 id_x  \
# 11      227's YouTube Chili' UCLA Chili' Bruins Sp...  1502202192656097285
# 12      227's YouTube Chili' UCLA Chili' Bruins Sp...  1502198154996830210
# 13  NBA Leader: 25.6 PPG This Day in History: 227'...  1502187340541923328
#
#    referenced_tweets              created_at_x  geo  retweet_count_x  \
# 11               NaN  2022-03-11T08:38:06.000Z  NaN                1
# 12               NaN  2022-03-11T08:22:04.000Z  NaN                0
# 13               NaN  2022-03-11T07:39:05.000Z  NaN                1
#
#     reply_count_x  like_count_x              created_at_y         username  \
# 11              0             0  2015-09-07T00:17:30.000Z  ucla_bruinchili
# 12              0             1  2015-09-07T00:17:30.000Z  ucla_bruinchili
# 13              0             0  2015-09-07T00:17:30.000Z  ucla_bruinchili
#
#                                           description        id_y  \
# 11  227's YouTube Chili' UCLA Chili' Bruins #JORDA...  3476038273
# 12  227's YouTube Chili' UCLA Chili' Bruins #JORDA...  3476038273
# 13  227's YouTube Chili' UCLA Chili' Bruins #JORDA...  3476038273
#
#              name  verified  followers_count_y  following_count_y  \
# 11  Jamaal Al-Din     False                 13                 36
# 12  Jamaal Al-Din     False                 13                 36
# 13  Jamaal Al-Din     False                 13                 36
#
#     tweet_count_y  listed_count_y
# 11          37448               0
# 12          37448               0
# 13          37448               0
